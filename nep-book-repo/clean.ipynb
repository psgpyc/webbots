# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('scrapped-csvs/thuprai_books.csv')

# %%
df.head()
# Out:
#                   title_english            title_nepali  \
# 0                        Nirved                 निर्वेद
# 1                      Phitkiri                 फिटकिरी
# 2  Colonel Chhatrabahadur Thapa  कर्णेल छत्रबहादुर थापा
# 3                  Bahadur Shah              बहादुर शाह
# 4                Chote Ra Motey             छोटे र मोटे
#
#                                  author_profile_link  \
# 0  https://www.thuprai.com/author/shailendra-adhi...
# 1          https://www.thuprai.com/author/sajan-k-c/
# 2        https://www.thuprai.com/author/kamal-thapa/
# 3   https://www.thuprai.com/author/chiranjibi-wagle/
# 4  https://www.thuprai.com/author/dr-dhruva-kumar...
#
#                 author_name  Audiobook  E-book Paperback Hardcover  \
# 0       Shailendra Adhikari        NaN     NaN       350       NaN
# 1                Sajan K.C.        NaN     NaN       375       NaN
# 2               Kamal Thapa        NaN     NaN       350       NaN
# ...

# %%
df['Audiobook'].fillna(0, inplace=True)
# Out:
# C:\Users\psgpy\AppData\Local\Temp\ipykernel_21388\3996784285.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Audiobook'].fillna(0, inplace=True)

# %%
df['E-book'].fillna(0, inplace=True)
# Out:
# C:\Users\psgpy\AppData\Local\Temp\ipykernel_21388\1289806738.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['E-book'].fillna(0, inplace=True)

# %%
df['Paperback'].fillna(0, inplace=True)
# Out:
# C:\Users\psgpy\AppData\Local\Temp\ipykernel_21388\2617279194.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Paperback'].fillna(0, inplace=True)

# %%
df['Hardcover'].fillna(0, inplace=True)
# Out:
# C:\Users\psgpy\AppData\Local\Temp\ipykernel_21388\3426619008.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Hardcover'].fillna(0, inplace=True)

# %%
df
# Out:
#                                      title_english  \
# 0                                           Nirved
# 1                                         Phitkiri
# 2                     Colonel Chhatrabahadur Thapa
# 3                                     Bahadur Shah
# 4                                   Chote Ra Motey
# ...                                            ...
# 4018                       Sabai Jaat ko Phoolbari
# 4019                            Tyo Ujyalo Karnali
# 4020      Niti DarpanBidur, Chanakya ra Bhatrihari
# 4021                          Mero Nepali: Grade 3
# 4022  Aafno Kavita Aafnai Aawaj - Rajendra Shalabh
#
#                                 title_nepali  \
# 0                                    निर्वेद
# 1                                    फिटकिरी
# 2                     कर्णेल छत्रबहादुर थापा
# 3                                 बहादुर शाह
# 4                                छोटे र मोटे
# ...                                      ...
# ...
